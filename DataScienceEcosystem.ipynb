# %% [markdown]
# ## Data Science Tools
#
# | Tool                | Description                                           |
# |---------------------|-------------------------------------------------------|
# | **Jupyter Notebook** | An open-source tool for creating and sharing documents with live code, visualizations, and explanatory text. |
# | **RStudio**         | An integrated development environment (IDE) for R, used for statistical computing and graphics. |
# | **Apache Spark**    | A distributed computing framework for big data processing and analytics. |
# | **Tableau**         | A powerful data visualization tool often used in business intelligence for creating interactive dashboards. |
# | **TensorFlow**      | An open-source library developed by Google for building and training machine learning and deep learning models. |
# | **Hadoop**          | An open-source framework that allows for distributed processing of large data sets across clusters of computers. |
# | **Microsoft Power BI** | A business analytics tool by Microsoft that provides data visualization and business intelligence capabilities. |
# | **SAS**             | A statistical software suite used for data management, advanced analytics, and predictive analysis. |
# | **Matplotlib**      | A Python library for creating static, animated, and interactive visualizations. |
# | **KNIME**           | An open-source platform for data analytics, reporting, and integration that supports machine learning. |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# Arithmetic expressions allow us to perform mathematical operations like addition, subtraction, multiplication, and division.
#
# Examples:
# - **Addition**: `3 + 5` evaluates to `8`
# - **Subtraction**: `10 - 4` evaluates to `6`
# - **Multiplication**: `6 * 7` evaluates to `42`
# - **Division**: `15 / 3` evaluates to `5`
# - **Exponentiation**: `2 ** 3` evaluates to `8`

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Describe commonly used libraries in Data Science
# - Identify key Data Science tools and ecosystems
# - Demonstrate basic arithmetic operations in Python

# %% [markdown]
# ## Author
# Rashmi

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Python Libraries
# Pandas: For data manipulation and analysis, especially with tabular data.
# NumPy: For numerical computations and working with arrays.
# Matplotlib and Seaborn: For data visualization.
# Scikit-Learn: For machine learning tasks like classification, regression, and clustering.
# TensorFlow and Keras: For deep learning and neural network models.
# NLTK and SpaCy: For natural language processing.
# Statsmodels: For statistical modeling and analysis.
# 2. R Libraries
# dplyr and tidyverse: For data manipulation and cleaning.
# ggplot2: For advanced data visualization.
# caret: For machine learning model training and tuning.
# randomForest and e1071: For machine learning algorithms like Random Forest and SVM.
# shiny: For building interactive web applications with data visualizations.
# 3. Big Data and Distributed Computing Libraries
# Apache Spark (PySpark for Python): For handling large-scale data and distributed computing.
# Hadoop: For distributed storage and processing of big data.
# 4. SQL and Database Interaction Libraries
# SQLAlchemy (Python): For database connections and management.
# DBI and RSQLite (R): For SQL database connections in R.
# 5. Data Wrangling and Transformation Libraries
# BeautifulSoup and Scrapy (Python): For web scraping to gather data.
# OpenCV (Python): For computer vision and image processing.

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. C

# %%
In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
